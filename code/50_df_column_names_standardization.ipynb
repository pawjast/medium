# %% [markdown]
# # Normalize column names in Pandas DataFrame

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Mock a (bad) DataFrame

# %%
df = pd.DataFrame(
    {
        " id": ["ID_1", "ID_2", "ID_3", "ID_4", "ID_5"],
        "name": ["Meg", "Bill", "Adam", "Alicia", "Akshay"],
        "surname ": ["Smith", "Khan", "Sanders", "O'Hara", "Johnson"],
        "years  employed": [2, 4, 5, 3, 10],
    }
)

# %%
df
# Out:
#      id    name surname   years  employed
# 0  ID_1     Meg    Smith                2
# 1  ID_2    Bill     Khan                4
# 2  ID_3    Adam  Sanders                5
# 3  ID_4  Alicia   O'Hara                3
# 4  ID_5  Akshay  Johnson               10

# %%
df["id"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/pj/courses/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df["id"]
#
# File ~/pj/courses/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/pj/courses/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'id'

# %%
df.columns
# Out:
# Index([' id', 'name', 'surname ', 'years  employed'], dtype='object')

# %%
df = pd.DataFrame(
    {
        " id": ["ID_1", "ID_2", "ID_3", "ID_4", "ID_5"],
        "Name": ["Meg", "Bill", "Adam", "Alicia", "Akshay"],
        "SURNAME": ["Smith", "Khan", "Sanders", "O'Hara", "Johnson"],
        "years-employed": [2, 4, 5, 3, 10],
        "position ": ["apprentice", "senior", "senior", "senior", "exec"],
        "contract/PERM": ["contract", "perm", "perm", "contract", "perm"],
        "work arrangement": ["office", "hybrid", "remote", "remote", "office"],
        "use.car.park?": ["no", "yes", "no", "no", "yes"],
    }
)

# %% [markdown]
# The columns look messy but in the preview there are still things you can't clearly see, like trailing/leading spaces.

# %%
df
# Out:
#      id    Name  SURNAME  years-employed   position  contract/PERM  \
# 0  ID_1     Meg    Smith               2  apprentice      contract
# 1  ID_2    Bill     Khan               4      senior          perm
# 2  ID_3    Adam  Sanders               5      senior          perm
# 3  ID_4  Alicia   O'Hara               3      senior      contract
# 4  ID_5  Akshay  Johnson              10        exec          perm
#
#   work arrangement use.car.park?
# 0           office            no
# 1           hybrid           yes
# 2           remote            no
# 3           remote            no
# 4           office           yes

# %%
df.columns
# Out:
# Index([' id', 'Name', 'SURNAME', 'years-employed', 'position ',
#        'contract/PERM', 'work arrangement', 'use.car.park?'],
#       dtype='object')

# %% [markdown]
# ## Accessing string methods of column index

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns.str

# %% [markdown]
# ### Strip trailing spaces

# %%
df.columns
# Out:
# Index([' id', 'Name', 'SURNAME', 'years-employed', 'position ',
#        'contract/PERM', 'work arrangement', 'use.car.park?'],
#       dtype='object')

# %%
df.columns.str.strip()
# Out:
# Index(['id', 'Name', 'SURNAME', 'years-employed', 'position', 'contract/PERM',
#        'work arrangement', 'use.car.park?'],
#       dtype='object')

# %% [markdown]
# ### Updating the column names
#
# String operations aren't `in place`.
# We need need to assign the changes back to the column variable.

# %%
df.columns
# Out:
# Index([' id', 'Name', 'SURNAME', 'years-employed', 'position ',
#        'contract/PERM', 'work arrangement', 'use.car.park?'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['id', 'Name', 'SURNAME', 'years-employed', 'position', 'contract/PERM',
#        'work arrangement', 'use.car.park?'],
#       dtype='object')

# %% [markdown]
# ### Normalize letters
#
# - Make them all "lower case" or "UPPER CASE" or "Title Case"

# %%
df.columns
# Out:
# Index(['id', 'Name', 'SURNAME', 'years-employed', 'position', 'contract/PERM',
#        'work arrangement', 'use.car.park?'],
#       dtype='object')

# %%
# Also check `.str.casefold()` method

# %%
df.columns.str.lower()
# Out:
# Index(['id', 'name', 'surname', 'years-employed', 'position', 'contract/perm',
#        'work arrangement', 'use.car.park?'],
#       dtype='object')

# %%
df.columns.str.upper()
# Out:
# Index(['ID', 'NAME', 'SURNAME', 'YEARS-EMPLOYED', 'POSITION', 'CONTRACT/PERM',
#        'WORK ARRANGEMENT', 'USE.CAR.PARK?'],
#       dtype='object')

# %%
df.columns.str.capitalize()
# Out:
# Index(['Id', 'Name', 'Surname', 'Years-employed', 'Position', 'Contract/perm',
#        'Work arrangement', 'Use.car.park?'],
#       dtype='object')

# %% [markdown]
# ### Chaining the operations
#
# In my case I want to go with the lower case normalization.

# %%
df.columns = (
    df.columns
        .str.strip()
        .str.lower()
)

# %%
df.columns
# Out:
# Index(['id', 'name', 'surname', 'years-employed', 'position', 'contract/perm',
#        'work arrangement', 'use.car.park?'],
#       dtype='object')

# %% [markdown]
# ### Replacing characters
#
# I like having all of the words separated with the underscore.
#
# I also used `.str.replace` to remove unwanted specific characters.

# %%
df.columns = (
    df.columns
        .str.strip()
        .str.lower()
        .str.replace(" ", "_")
        .str.replace("-", "_")
        .str.replace(".", "_")
        .str.replace("/", "_")
        .str.replace("?", "")  # remove `?`
)

# %%
df.columns
# Out:
# Index(['id', 'name', 'surname', 'years_employed', 'position', 'contract_perm',
#        'work_arrangement', 'use_car_park'],
#       dtype='object')

# %% [markdown]
# ## Wrap operation into a reusable function

# %%
def normalize_column_names(df: pd.DataFrame) -> pd.DataFrame:
    """Clean the DataFrame's column names
    """
    df = df.copy()

    df.columns = (
        df.columns
            .str.strip()
            .str.lower()
            .str.replace(" ", "_")
            .str.replace("-", "_")
            .str.replace(".", "_")
            .str.replace("/", "_")
            .str.replace("?", "")
    )

    return df

# %%
df = pd.DataFrame(
    {
        " id": ["ID_1", "ID_2", "ID_3", "ID_4", "ID_5"],
        "Name": ["Meg", "Bill", "Adam", "Alicia", "Akshay"],
        "SURNAME": ["Smith", "Khan", "Sanders", "O'Hara", "Johnson"],
        "years-employed": [2, 4, 5, 3, 10],
        "position ": ["apprentice", "senior", "senior", "senior", "exec"],
        "contract/PERM": ["contract", "perm", "perm", "contract", "perm"],
        "work arrangement": ["office", "hybrid", "remote", "remote", "office"],
        "use.car.park?": ["no", "yes", "no", "no", "yes"],
    }
)

# %%
df.columns
# Out:
# Index([' id', 'Name', 'SURNAME', 'years-employed', 'position ',
#        'contract/PERM', 'work arrangement', 'use.car.park?'],
#       dtype='object')

# %%
clean_df = normalize_column_names(df)

# %%
clean_df.columns
# Out:
# Index(['id', 'name', 'surname', 'years_employed', 'position', 'contract_perm',
#        'work_arrangement', 'use_car_park'],
#       dtype='object')

# %% [markdown]
# ## Use regexp for more tricky cases
#
# Lots of cleaning can be done with string methods alone. But regexp can help handle more tricky cases.

# %% [markdown]
# ### Provide a list of characters to replace with the underscore

# %%
df = pd.DataFrame(
    {
        " id": ["ID_1", "ID_2", "ID_3", "ID_4", "ID_5"],
        "Name": ["Meg", "Bill", "Adam", "Alicia", "Akshay"],
        "SURNAME": ["Smith", "Khan", "Sanders", "O'Hara", "Johnson"],
        "years-employed": [2, 4, 5, 3, 10],
        "position ": ["apprentice", "senior", "senior", "senior", "exec"],
        "contract/PERM": ["contract", "perm", "perm", "contract", "perm"],
        "work arrangement": ["office", "hybrid", "remote", "remote", "office"],
        "use.car.park?": ["no", "yes", "no", "no", "yes"],
        "#made    up column_1*": [True, False, False, True, True],
        "made\tup\ncolumn_2": [0, 1, 2, 3, 4],
    }
)

# %%
df
# Out:
#      id    Name  SURNAME  years-employed   position  contract/PERM  \
# 0  ID_1     Meg    Smith               2  apprentice      contract
# 1  ID_2    Bill     Khan               4      senior          perm
# 2  ID_3    Adam  Sanders               5      senior          perm
# 3  ID_4  Alicia   O'Hara               3      senior      contract
# 4  ID_5  Akshay  Johnson              10        exec          perm
#
#   work arrangement use.car.park?  #made    up column_1*  made\tup\ncolumn_2
# 0           office            no                   True                   0
# 1           hybrid           yes                  False                   1
# 2           remote            no                  False                   2
# 3           remote            no                   True                   3
# 4           office           yes                   True                   4

# %%
df.columns
# Out:
# Index([' id', 'Name', 'SURNAME', 'years-employed', 'position ',
#        'contract/PERM', 'work arrangement', 'use.car.park?',
#        '#made    up column_1*', 'made\tup\ncolumn_2'],
#       dtype='object')

# %%
df.columns = (
    df.columns
        .str.strip()
        .str.lower()
        .str.replace(r"[ \-./]", "_", regex=True)
        .str.replace(r"[?*#]", "", regex=True)
)

# %%
df.columns
# Out:
# Index(['id', 'name', 'surname', 'years_employed', 'position', 'contract_perm',
#        'work_arrangement', 'use_car_park', 'made____up_column_1',
#        'made\tup\ncolumn_2'],
#       dtype='object')

# %% [markdown]
# There's a problem as one of the columns had multiple spaces and they got replaced with multiple underscores.

# %%
df = pd.DataFrame(
    {
        " id": ["ID_1", "ID_2", "ID_3", "ID_4", "ID_5"],
        "Name": ["Meg", "Bill", "Adam", "Alicia", "Akshay"],
        "SURNAME": ["Smith", "Khan", "Sanders", "O'Hara", "Johnson"],
        "years-employed": [2, 4, 5, 3, 10],
        "position ": ["apprentice", "senior", "senior", "senior", "exec"],
        "contract/PERM": ["contract", "perm", "perm", "contract", "perm"],
        "work arrangement": ["office", "hybrid", "remote", "remote", "office"],
        "use.car.park?": ["no", "yes", "no", "no", "yes"],
        "#made    up column_1*": [True, False, False, True, True],
        "made\tup\ncolumn_2": [0, 1, 2, 3, 4],
    }
)

# %%
df.columns
# Out:
# Index([' id', 'Name', 'SURNAME', 'years-employed', 'position ',
#        'contract/PERM', 'work arrangement', 'use.car.park?',
#        '#made    up column_1*', 'made\tup\ncolumn_2'],
#       dtype='object')

# %%
df.columns = (
    df.columns
        .str.strip()
        .str.lower()
        .str.replace(r"\s+", "_", regex=True)
        .str.replace(r"[\-./]", "_", regex=True)
        .str.replace(r"[?*#]", "", regex=True)
)

# %%
df.columns
# Out:
# Index(['id', 'name', 'surname', 'years_employed', 'position', 'contract_perm',
#        'work_arrangement', 'use_car_park', 'made_up_column_1',
#        'made_up_column_2'],
#       dtype='object')
