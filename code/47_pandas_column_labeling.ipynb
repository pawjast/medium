# %% [markdown]
# # Learning how to use apply label columns to DataFrame with `pd.cut()`, `np.select`, `df.map()`

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import random
from datetime import datetime
import numpy as np

# %%
random.seed(1)

# %%
pd.options.display.float_format = "{:,.3f}".format

# %% [markdown]
# ## Mock DataFrame 1

# %%
nr_of_rand_points = 16

# %%
df = pd.DataFrame(
    {
        "float": sorted([random.random() for _ in range(nr_of_rand_points)]),
    },

)

df
# Out:
#     float
# 0   0.002
# 1   0.028
# 2   0.094
# 3   0.134
# 4   0.255
# 5   0.433
# 6   0.445
# 7   0.449
# 8   0.495
# 9   0.652
# 10  0.722
# 11  0.762
# 12  0.764
# 13  0.789
# 14  0.836
# 15  0.847

# %% [markdown]
# ## The old way

# %% [markdown]
# ### Create columns with labels to populate

# %%
df["label"] = ""

# %%
df
# Out:
#     float label
# 0   0.002
# 1   0.028
# 2   0.094
# 3   0.134
# 4   0.255
# 5   0.433
# 6   0.445
# 7   0.449
# 8   0.495
# 9   0.652
# 10  0.722
# 11  0.762
# 12  0.764
# 13  0.789
# 14  0.836
# 15  0.847

# %% [markdown]
# ### Mask 1

# %%
mask_1 = df["float"] < 0.2
mask_1
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: float, dtype: bool

# %%
df.loc[mask_1, "label"] = "bottom"

# %%
df
# Out:
#     float   label
# 0   0.002  bottom
# 1   0.028  bottom
# 2   0.094  bottom
# 3   0.134  bottom
# 4   0.255
# 5   0.433
# 6   0.445
# 7   0.449
# 8   0.495
# 9   0.652
# 10  0.722
# 11  0.762
# 12  0.764
# 13  0.789
# 14  0.836
# 15  0.847

# %% [markdown]
# ### Mask 2

# %%
mask_2 = df["float"] >= 0.8
mask_2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# Name: float, dtype: bool

# %%
df.loc[mask_2, "label"] = "top"

# %%
df
# Out:
#     float   label
# 0   0.002  bottom
# 1   0.028  bottom
# 2   0.094  bottom
# 3   0.134  bottom
# 4   0.255
# 5   0.433
# 6   0.445
# 7   0.449
# 8   0.495
# 9   0.652
# 10  0.722
# 11  0.762
# 12  0.764
# 13  0.789
# 14  0.836     top
# 15  0.847     top

# %% [markdown]
# ### Mask 3

# %%
mask_3 = (df["float"] >= 0.2) & (df["float"] < 0.8)
mask_3
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# Name: float, dtype: bool

# %%
df.loc[mask_3, "label"] = "middle"

# %%
df
# Out:
#     float   label
# 0   0.002  bottom
# 1   0.028  bottom
# 2   0.094  bottom
# 3   0.134  bottom
# 4   0.255  middle
# 5   0.433  middle
# 6   0.445  middle
# 7   0.449  middle
# 8   0.495  middle
# 9   0.652  middle
# 10  0.722  middle
# 11  0.762  middle
# 12  0.764  middle
# 13  0.789  middle
# 14  0.836     top
# 15  0.847     top

# %% [markdown]
# ### Label column type
#
# Manual column labeling creates an `object` type which is used for strings.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   float   16 non-null     float64
#  1   label   16 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 388.0+ bytes

# %% [markdown]
# ## The cut way 1
#
# Good for a single condition.

# %%
# Create 3 bins
# Each bin must have start and end
# 4 values creates 3 bins
bins = [0, 0.2, 0.8, 1]

# %%
labels = ["b", "m", "t"]

# %%
df["label_cut"] = pd.cut(
    x=df["float"],
    bins=bins,
    labels=labels
)

# %%
df
# Out:
#     float   label label_cut
# 0   0.002  bottom         b
# 1   0.028  bottom         b
# 2   0.094  bottom         b
# 3   0.134  bottom         b
# 4   0.255  middle         m
# 5   0.433  middle         m
# 6   0.445  middle         m
# 7   0.449  middle         m
# 8   0.495  middle         m
# 9   0.652  middle         m
# 10  0.722  middle         m
# 11  0.762  middle         m
# 12  0.764  middle         m
# 13  0.789  middle         m
# 14  0.836     top         t
# 15  0.847     top         t

# %% [markdown]
# ### Label column type
#
# The `cut` function uses `categorical` type for label column. This is more efficient and faster.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   float      16 non-null     float64
#  1   label      16 non-null     object
#  2   label_cut  16 non-null     category
# dtypes: category(1), float64(1), object(1)
# memory usage: 536.0+ bytes

# %% [markdown]
# ## The cut way 2
#
# Let's add datetime index.

# %%
start_date = datetime(
    year=2025,
    month=6,
    day=1,
    hour=11,
    minute=52,
    second=0,
)

start_date
# Out:
# datetime.datetime(2025, 6, 1, 11, 52)

# %%
timestamp_index = pd.date_range(
    start=start_date,
    periods=nr_of_rand_points,
    freq="min"
)

# %%
timestamp_index
# Out:
# DatetimeIndex(['2025-06-01 11:52:00', '2025-06-01 11:53:00',
#                '2025-06-01 11:54:00', '2025-06-01 11:55:00',
#                '2025-06-01 11:56:00', '2025-06-01 11:57:00',
#                '2025-06-01 11:58:00', '2025-06-01 11:59:00',
#                '2025-06-01 12:00:00', '2025-06-01 12:01:00',
#                '2025-06-01 12:02:00', '2025-06-01 12:03:00',
#                '2025-06-01 12:04:00', '2025-06-01 12:05:00',
#                '2025-06-01 12:06:00', '2025-06-01 12:07:00'],
#               dtype='datetime64[ns]', freq='min')

# %%
mid_point = timestamp_index[8]
mid_point
# Out:
# Timestamp('2025-06-01 12:00:00')

# %%
df = pd.DataFrame(
    {
        "float": sorted([random.random() for _ in range(nr_of_rand_points)]),
    },
    index=timestamp_index,
)

df
# Out:
#                      float
# 2025-06-01 11:52:00  0.025
# 2025-06-01 11:53:00  0.029
# 2025-06-01 11:54:00  0.031
# 2025-06-01 11:55:00  0.217
# 2025-06-01 11:56:00  0.222
# 2025-06-01 11:57:00  0.229
# 2025-06-01 11:58:00  0.231
# 2025-06-01 11:59:00  0.233
# 2025-06-01 12:00:00  0.381
# 2025-06-01 12:01:00  0.422
# 2025-06-01 12:02:00  0.438
# 2025-06-01 12:03:00  0.496
# 2025-06-01 12:04:00  0.541
# 2025-06-01 12:05:00  0.901
# 2025-06-01 12:06:00  0.939
# 2025-06-01 12:07:00  0.945

# %%
bins_t = [
    timestamp_index[0],
    mid_point,
    timestamp_index[-1]
]

# %%
bins_t
# Out:
# [Timestamp('2025-06-01 11:52:00'),
#  Timestamp('2025-06-01 12:00:00'),
#  Timestamp('2025-06-01 12:07:00')]

# %%
labels_t = ["morning", "noon"]

# %%
df["time_of_day"] = pd.cut(
    x=df.index,
    bins=bins_t,
    labels=labels_t
)

# %%
df
# Out:
#                      float time_of_day
# 2025-06-01 11:52:00  0.025         NaN
# 2025-06-01 11:53:00  0.029     morning
# 2025-06-01 11:54:00  0.031     morning
# 2025-06-01 11:55:00  0.217     morning
# 2025-06-01 11:56:00  0.222     morning
# 2025-06-01 11:57:00  0.229     morning
# 2025-06-01 11:58:00  0.231     morning
# 2025-06-01 11:59:00  0.233     morning
# 2025-06-01 12:00:00  0.381     morning
# 2025-06-01 12:01:00  0.422        noon
# 2025-06-01 12:02:00  0.438        noon
# 2025-06-01 12:03:00  0.496        noon
# 2025-06-01 12:04:00  0.541        noon
# 2025-06-01 12:05:00  0.901        noon
# 2025-06-01 12:06:00  0.939        noon
# 2025-06-01 12:07:00  0.945        noon

# %% [markdown]
# ### Be inclusive of all values
#
# As seen above, the default option is to have every bin open ended on the left  so it's `(start, end]`.
# Adding `include_lowest=True` will make the first bin close ended on both sides: `[start, end]`

# %%
df["time_of_day_2"] = pd.cut(
    x=df.index,
    bins=bins_t,
    labels=labels_t,
    include_lowest=True,
)

# %%
df
# Out:
#                      float time_of_day time_of_day_2
# 2025-06-01 11:52:00  0.025         NaN       morning
# 2025-06-01 11:53:00  0.029     morning       morning
# 2025-06-01 11:54:00  0.031     morning       morning
# 2025-06-01 11:55:00  0.217     morning       morning
# 2025-06-01 11:56:00  0.222     morning       morning
# 2025-06-01 11:57:00  0.229     morning       morning
# 2025-06-01 11:58:00  0.231     morning       morning
# 2025-06-01 11:59:00  0.233     morning       morning
# 2025-06-01 12:00:00  0.381     morning       morning
# 2025-06-01 12:01:00  0.422        noon          noon
# 2025-06-01 12:02:00  0.438        noon          noon
# 2025-06-01 12:03:00  0.496        noon          noon
# 2025-06-01 12:04:00  0.541        noon          noon
# 2025-06-01 12:05:00  0.901        noon          noon
# 2025-06-01 12:06:00  0.939        noon          noon
# 2025-06-01 12:07:00  0.945        noon          noon

# %% [markdown]
# ### Change the the inclusion from right to left
#
# So each bin is `[start, end)`

# %%
df["time_of_day_3"] = pd.cut(
    x=df.index,
    bins=bins_t,
    labels=labels_t,
    right=False,
)

# %%
df
# Out:
#                      float time_of_day time_of_day_2 time_of_day_3
# 2025-06-01 11:52:00  0.025         NaN       morning       morning
# 2025-06-01 11:53:00  0.029     morning       morning       morning
# 2025-06-01 11:54:00  0.031     morning       morning       morning
# 2025-06-01 11:55:00  0.217     morning       morning       morning
# 2025-06-01 11:56:00  0.222     morning       morning       morning
# 2025-06-01 11:57:00  0.229     morning       morning       morning
# 2025-06-01 11:58:00  0.231     morning       morning       morning
# 2025-06-01 11:59:00  0.233     morning       morning       morning
# 2025-06-01 12:00:00  0.381     morning       morning          noon
# 2025-06-01 12:01:00  0.422        noon          noon          noon
# 2025-06-01 12:02:00  0.438        noon          noon          noon
# 2025-06-01 12:03:00  0.496        noon          noon          noon
# 2025-06-01 12:04:00  0.541        noon          noon          noon
# 2025-06-01 12:05:00  0.901        noon          noon          noon
# 2025-06-01 12:06:00  0.939        noon          noon          noon
# 2025-06-01 12:07:00  0.945        noon          noon           NaN

# %% [markdown]
# The last value is now not captured so in order to get it we need to make sure the last value in the bin is bigger than the last timestamp in the index.

# %%
bins_tt = [
    timestamp_index[0],
    mid_point,
    timestamp_index[-1] + pd.Timedelta("1ns")
]

# %%
bins_tt
# Out:
# [Timestamp('2025-06-01 11:52:00'),
#  Timestamp('2025-06-01 12:00:00'),
#  Timestamp('2025-06-01 12:07:00.000000001')]

# %%
df["time_of_day_4"] = pd.cut(
    x=df.index,
    bins=bins_tt,
    labels=labels_t,
    right=False,
)

# %%
df
# Out:
#                      float time_of_day time_of_day_2 time_of_day_3  \
# 2025-06-01 11:52:00  0.025         NaN       morning       morning
# 2025-06-01 11:53:00  0.029     morning       morning       morning
# 2025-06-01 11:54:00  0.031     morning       morning       morning
# 2025-06-01 11:55:00  0.217     morning       morning       morning
# 2025-06-01 11:56:00  0.222     morning       morning       morning
# 2025-06-01 11:57:00  0.229     morning       morning       morning
# 2025-06-01 11:58:00  0.231     morning       morning       morning
# 2025-06-01 11:59:00  0.233     morning       morning       morning
# 2025-06-01 12:00:00  0.381     morning       morning          noon
# 2025-06-01 12:01:00  0.422        noon          noon          noon
# 2025-06-01 12:02:00  0.438        noon          noon          noon
# 2025-06-01 12:03:00  0.496        noon          noon          noon
# 2025-06-01 12:04:00  0.541        noon          noon          noon
# 2025-06-01 12:05:00  0.901        noon          noon          noon
# 2025-06-01 12:06:00  0.939        noon          noon          noon
# 2025-06-01 12:07:00  0.945        noon          noon           NaN
#
#                     time_of_day_4
# 2025-06-01 11:52:00       morning
# 2025-06-01 11:53:00       morning
# 2025-06-01 11:54:00       morning
# 2025-06-01 11:55:00       morning
# 2025-06-01 11:56:00       morning
# 2025-06-01 11:57:00       morning
# 2025-06-01 11:58:00       morning
# 2025-06-01 11:59:00       morning
# 2025-06-01 12:00:00          noon
# 2025-06-01 12:01:00          noon
# 2025-06-01 12:02:00          noon
# 2025-06-01 12:03:00          noon
# 2025-06-01 12:04:00          noon
# 2025-06-01 12:05:00          noon
# 2025-06-01 12:06:00          noon
# 2025-06-01 12:07:00          noon

# %% [markdown]
# ## The cut way 3 with a default value

# %%
bins_ttt = [
    timestamp_index[4],
    timestamp_index[9]
]

# %%
bins_ttt
# Out:
# [Timestamp('2025-06-01 11:56:00'), Timestamp('2025-06-01 12:01:00')]

# %%
df["time_of_day_5"] = pd.cut(
    x=df.index,
    bins=bins_ttt,
    labels=["mid point"],
    right=False,
).add_categories("??").fillna("??")

# %%
df
# Out:
#                      float time_of_day time_of_day_2 time_of_day_3  \
# 2025-06-01 11:52:00  0.025         NaN       morning       morning
# 2025-06-01 11:53:00  0.029     morning       morning       morning
# 2025-06-01 11:54:00  0.031     morning       morning       morning
# 2025-06-01 11:55:00  0.217     morning       morning       morning
# 2025-06-01 11:56:00  0.222     morning       morning       morning
# 2025-06-01 11:57:00  0.229     morning       morning       morning
# 2025-06-01 11:58:00  0.231     morning       morning       morning
# 2025-06-01 11:59:00  0.233     morning       morning       morning
# 2025-06-01 12:00:00  0.381     morning       morning          noon
# 2025-06-01 12:01:00  0.422        noon          noon          noon
# 2025-06-01 12:02:00  0.438        noon          noon          noon
# 2025-06-01 12:03:00  0.496        noon          noon          noon
# 2025-06-01 12:04:00  0.541        noon          noon          noon
# 2025-06-01 12:05:00  0.901        noon          noon          noon
# 2025-06-01 12:06:00  0.939        noon          noon          noon
# 2025-06-01 12:07:00  0.945        noon          noon           NaN
#
#                     time_of_day_4 time_of_day_5
# 2025-06-01 11:52:00       morning            ??
# 2025-06-01 11:53:00       morning            ??
# 2025-06-01 11:54:00       morning            ??
# 2025-06-01 11:55:00       morning            ??
# 2025-06-01 11:56:00       morning     mid point
# 2025-06-01 11:57:00       morning     mid point
# 2025-06-01 11:58:00       morning     mid point
# 2025-06-01 11:59:00       morning     mid point
# 2025-06-01 12:00:00          noon     mid point
# 2025-06-01 12:01:00          noon            ??
# 2025-06-01 12:02:00          noon            ??
# 2025-06-01 12:03:00          noon            ??
# 2025-06-01 12:04:00          noon            ??
# 2025-06-01 12:05:00          noon            ??
# 2025-06-01 12:06:00          noon            ??
# 2025-06-01 12:07:00          noon            ??

# %% [markdown]
# ## The select way

# %%
df = pd.DataFrame(
    {
        "float": sorted([random.random() for _ in range(nr_of_rand_points)]),
    },

)

df
# Out:
#     float
# 0   0.021
# 1   0.121
# 2   0.186
# 3   0.219
# 4   0.290
# 5   0.333
# 6   0.422
# 7   0.460
# 8   0.556
# 9   0.642
# 10  0.711
# 11  0.721
# 12  0.838
# 13  0.860
# 14  0.936
# 15  0.993

# %% [markdown]
# ### Recreate first example with the masks

# %%
conditions = [
    df["float"] < 0.2,
    df["float"] >= 0.8,
    (df["float"] >= 0.2) & (df["float"] < 0.8),
]

# %%
conditions
# Out:
# [0      True
#  1      True
#  2      True
#  3     False
#  4     False
#  5     False
#  6     False
#  7     False
#  8     False
#  9     False
#  10    False
#  11    False
#  12    False
#  13    False
#  14    False
#  15    False
#  Name: float, dtype: bool,
#  0     False
#  1     False
#  2     False
#  3     False
#  4     False
#  5     False
#  6     False
#  7     False
#  8     False
#  9     False
#  10    False
#  11    False
#  12     True
#  13     True
#  14     True
#  15     True
#  Name: float, dtype: bool,
#  0     False
#  1     False
#  2     False
#  3      True
#  4      True
#  5      True
#  6      True
#  7      True
#  8      True
#  9      True
#  10     True
#  11     True
#  12    False
#  13    False
#  14    False
#  15    False
#  Name: float, dtype: bool]

# %%
labels = ["less than 0.2", "more than 0.8", "middle"]
labels
# Out:
# ['less than 0.2', 'more than 0.8', 'middle']

# %%
df["labels_select"] = np.select(
    condlist=conditions,
    choicelist=labels,
    default="??"
)

# %%
df
# Out:
#     float  labels_select
# 0   0.021  less than 0.2
# 1   0.121  less than 0.2
# 2   0.186  less than 0.2
# 3   0.219         middle
# 4   0.290         middle
# 5   0.333         middle
# 6   0.422         middle
# 7   0.460         middle
# 8   0.556         middle
# 9   0.642         middle
# 10  0.711         middle
# 11  0.721         middle
# 12  0.838  more than 0.8
# 13  0.860  more than 0.8
# 14  0.936  more than 0.8
# 15  0.993  more than 0.8

# %% [markdown]
# ### Label column type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   float          16 non-null     float64
#  1   labels_select  16 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 388.0+ bytes

# %% [markdown]
# ## Mapping
#
# For 1 to 1 mapping of labels.

# %% [markdown]
# ### Mock DataFrame 2

# %%
df = pd.DataFrame(
    {
        "int": sorted([random.randrange(-20, 20) for _ in range(16)])
    },

)

df
# Out:
#     int
# 0   -18
# 1    -9
# 2    -8
# 3    -5
# 4    -2
# 5    -1
# 6     3
# 7     5
# 8     5
# 9     6
# 10   10
# 11   11
# 12   12
# 13   15
# 14   17
# 15   17

# %% [markdown]
# ### Example 1

# %%
df["mapped_1"] = df["int"].map(lambda x: 1 if x > 0 else 0)

# %%
df
# Out:
#     int  mapped_1
# 0   -18         0
# 1    -9         0
# 2    -8         0
# 3    -5         0
# 4    -2         0
# 5    -1         0
# 6     3         1
# 7     5         1
# 8     5         1
# 9     6         1
# 10   10         1
# 11   11         1
# 12   12         1
# 13   15         1
# 14   17         1
# 15   17         1

# %% [markdown]
# ### Example 2
#
# Mapping using dictionary

# %%
mapped_vals = {
    0: "negative",
    1: "positive",
}

# %%
df["mapped_2"] = df["mapped_1"].map(mapped_vals)

# %%
df
# Out:
#     int  mapped_1  mapped_2
# 0   -18         0  negative
# 1    -9         0  negative
# 2    -8         0  negative
# 3    -5         0  negative
# 4    -2         0  negative
# 5    -1         0  negative
# 6     3         1  positive
# 7     5         1  positive
# 8     5         1  positive
# 9     6         1  positive
# 10   10         1  positive
# 11   11         1  positive
# 12   12         1  positive
# 13   15         1  positive
# 14   17         1  positive
# 15   17         1  positive

# %% [markdown]
# ### Label column type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   int       16 non-null     int64
#  1   mapped_1  16 non-null     int64
#  2   mapped_2  16 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 516.0+ bytes
