# %% [markdown]
# # Work with categorical variables in Pandas

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype

# For mocking data
import random
from string import ascii_lowercase
import numpy as np

# %% [markdown]
# ## f: mock_df
#
# Function that mocks the data.

# %%
def mock_df(nr_of_samples: int = 100, seed=0):
    random.seed(seed)

    df = pd.DataFrame.from_dict(
        {
            "age": [random.randrange(18, 65) for _ in range(nr_of_samples)],
            "coding_exp": [random.choice(["beginner", "intermediate", "pro"]) for _ in range(nr_of_samples)],
            "title": [random.choice(["peasant", "bishop", "merchant", "knight", "king"]) for _ in range(nr_of_samples)],
            "fav_myth_creature": [random.choice(["Big Foot", "Dragon", "Phoenix", "Unicorn", "Vampire", "Werewolf"]) for _ in range(nr_of_samples)],
            "fav_3_letters": ["".join(random.choices(ascii_lowercase, k=3)) for _ in range(nr_of_samples)],
            "secret_group": [random.randrange(1, 5) for _ in range(nr_of_samples)],
        },
        orient="columns",
    )

    return df

# %% [markdown]
# ## The Data

# %%
df = mock_df()

# %%
df
# Out:
#     age    coding_exp     title fav_myth_creature fav_3_letters  secret_group
# 0    42           pro   peasant          Big Foot           kcx             3
# 1    44  intermediate      king          Werewolf           mvz             2
# 2    20  intermediate    knight          Big Foot           ims             4
# 3    34      beginner   peasant          Werewolf           lht             4
# 4    50      beginner      king           Vampire           xxq             1
# ..  ...           ...       ...               ...           ...           ...
# 95   29           pro    knight          Big Foot           tlg             4
# 96   30  intermediate    knight           Phoenix           lyd             4
# 97   29  intermediate  merchant           Unicorn           mqm             2
# 98   20  intermediate   peasant           Phoenix           fas             4
# 99   57      beginner    bishop           Phoenix           qah             2
#
# [100 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
df.dtypes
# Out:
# age                   int64
# coding_exp           object
# title                object
# fav_myth_creature    object
# fav_3_letters        object
# secret_group          int64
# dtype: object

# %% [markdown]
# ## Check number of unique values in each column

# %%
for col in df.select_dtypes(include="object"):
    print(f"{col} - nr of unique entries: {df[col].nunique()} out of {len(df)} ({100* df[col].nunique() / len(df): .1f}%)")
# Out:
# coding_exp - nr of unique entries: 3 out of 100 ( 3.0%)
# title - nr of unique entries: 5 out of 100 ( 5.0%)
# fav_myth_creature - nr of unique entries: 6 out of 100 ( 6.0%)
# fav_3_letters - nr of unique entries: 99 out of 100 ( 99.0%)

# %% [markdown]
# ## Convert an individual column to categorical

# %%
df["coding_exp"] = df["coding_exp"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    category
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: category(1), int64(2), object(3)
# memory usage: 4.3+ KB

# %%
df["coding_exp"]
# Out:
# 0              pro
# 1     intermediate
# 2     intermediate
# 3         beginner
# 4         beginner
#           ...
# 95             pro
# 96    intermediate
# 97    intermediate
# 98    intermediate
# 99        beginner
# Name: coding_exp, Length: 100, dtype: category
# Categories (3, object): ['beginner', 'intermediate', 'pro']

# %%
# Convert remaining columns one by one

# %%
df["title"] = df["fav_myth_creature"].astype("category")
df["fav_myth_creature"] = df["fav_myth_creature"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    category
#  2   title              100 non-null    category
#  3   fav_myth_creature  100 non-null    category
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: category(3), int64(2), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Convert all columns at once
#
# Based on our previous exploration we know it doesn't make sense for this dataset specifically. But if it makes sense for your dataset, this is how to do it.

# %%
# Let's recreate the df
df = mock_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
df = df.astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    category
#  1   coding_exp         100 non-null    category
#  2   title              100 non-null    category
#  3   fav_myth_creature  100 non-null    category
#  4   fav_3_letters      100 non-null    category
#  5   secret_group       100 non-null    category
# dtypes: category(6)
# memory usage: 5.7 KB

# %% [markdown]
# ## Explore categorical variables

# %%
df = mock_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# ### Convert one column to categorical

# %%
df["fav_myth_creature"] = df["fav_myth_creature"].astype("category")

# %%
df.dtypes
# Out:
# age                     int64
# coding_exp             object
# title                  object
# fav_myth_creature    category
# fav_3_letters          object
# secret_group            int64
# dtype: object

# %%
df["fav_myth_creature"]
# Out:
# 0     Big Foot
# 1     Werewolf
# 2     Big Foot
# 3     Werewolf
# 4      Vampire
#         ...
# 95    Big Foot
# 96     Phoenix
# 97     Unicorn
# 98     Phoenix
# 99     Phoenix
# Name: fav_myth_creature, Length: 100, dtype: category
# Categories (6, object): ['Big Foot', 'Dragon', 'Phoenix', 'Unicorn', 'Vampire', 'Werewolf']

# %% [markdown]
# ### Read categories
#
# `df[column].cat.<method>`

# %%
# These are alphabetical
df["fav_myth_creature"].cat.categories
# Out:
# Index(['Big Foot', 'Dragon', 'Phoenix', 'Unicorn', 'Vampire', 'Werewolf'], dtype='object')

# %% [markdown]
# ### Read codes

# %%
df["fav_myth_creature"].cat.codes
# Out:
# 0     0
# 1     5
# 2     0
# 3     5
# 4     4
#      ..
# 95    0
# 96    2
# 97    3
# 98    2
# 99    2
# Length: 100, dtype: int8

# %% [markdown]
# ## Categories: unordered vs ordered

# %%
df = mock_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# ### Unordered

# %%
# By default it's unordered category
df["coding_exp"] = df["coding_exp"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    category
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: category(1), int64(2), object(3)
# memory usage: 4.3+ KB

# %%
df["coding_exp"]
# Out:
# 0              pro
# 1     intermediate
# 2     intermediate
# 3         beginner
# 4         beginner
#           ...
# 95             pro
# 96    intermediate
# 97    intermediate
# 98    intermediate
# 99        beginner
# Name: coding_exp, Length: 100, dtype: category
# Categories (3, object): ['beginner', 'intermediate', 'pro']

# %%
# Some of the descriptive stat functions won't work with unordered category

df["coding_exp"].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 # Some of the descriptive stat functions won't work with unordered category
# ----> 3 df["coding_exp"].min()
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/series.py:6518, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6510 @doc(make_doc("min", ndim=1))
#    6511 def min(
#    6512     self,
#    (...)   6516     **kwargs,
#    6517 ):
# -> 6518     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12407, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12400 def min(
#   12401     self,
#   12402     axis: Axis | None = 0,
#    (...)  12405     **kwargs,
#   12406 ):
# > 12407     return self._stat_function(
#   12408         "min",
#   12409         nanops.nanmin,
#   12410         axis,
#   12411         skipna,
#   12412         numeric_only,
#   12413         **kwargs,
#   12414     )
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/series.py:6454, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6450     self._get_axis_number(axis)
#    6452 if isinstance(delegate, ExtensionArray):
#    6453     # dispatch to ExtensionArray interface
# -> 6454     return delegate._reduce(name, skipna=skipna, **kwds)
#    6456 else:
#    6457     # dispatch to numpy arrays
#    6458     if numeric_only and self.dtype.kind not in "iufcb":
#    6459         # i.e. not is_numeric_dtype(self.dtype)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:2391, in Categorical._reduce(self, name, skipna, keepdims, **kwargs)
#    2388 def _reduce(
#    2389     self, name: str, *, skipna: bool = True, keepdims: bool = False, **kwargs
#    2390 ):
# -> 2391     result = super()._reduce(name, skipna=skipna, keepdims=keepdims, **kwargs)
#    2392     if name in ["argmax", "argmin"]:
#    2393         # don't wrap in Categorical!
#    2394         return result
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/base.py:1958, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1953 if meth is None:
#    1954     raise TypeError(
#    1955         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1956         f"does not support reduction '{name}'"
#    1957     )
# -> 1958 result = meth(skipna=skipna, **kwargs)
#    1959 if keepdims:
#    1960     result = np.array([result])
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:2417, in Categorical.min(self, skipna, **kwargs)
#    2415 nv.validate_minmax_axis(kwargs.get("axis", 0))
#    2416 nv.validate_min((), kwargs)
# -> 2417 self.check_for_ordered("min")
#    2419 if not len(self._codes):
#    2420     return self.dtype.na_value
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:1901, in Categorical.check_for_ordered(self, op)
#    1899 """assert that we are ordered"""
#    1900 if not self.ordered:
# -> 1901     raise TypeError(
#    1902         f"Categorical is not ordered for operation {op}\n"
#    1903         "you can use .as_ordered() to change the "
#    1904         "Categorical to an ordered one\n"
#    1905     )
#
# TypeError: Categorical is not ordered for operation min
# you can use .as_ordered() to change the Categorical to an ordered one

# %%
df["coding_exp"].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df["coding_exp"].max()
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/series.py:6528, in Series.max(self, axis, skipna, numeric_only, **kwargs)
#    6520 @doc(make_doc("max", ndim=1))
#    6521 def max(
#    6522     self,
#    (...)   6526     **kwargs,
#    6527 ):
# -> 6528     return NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12423, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12416 def max(
#   12417     self,
#   12418     axis: Axis | None = 0,
#    (...)  12421     **kwargs,
#   12422 ):
# > 12423     return self._stat_function(
#   12424         "max",
#   12425         nanops.nanmax,
#   12426         axis,
#   12427         skipna,
#   12428         numeric_only,
#   12429         **kwargs,
#   12430     )
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12396, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12392 nv.validate_func(name, (), kwargs)
#   12394 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12396 return self._reduce(
#   12397     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12398 )
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/series.py:6454, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6450     self._get_axis_number(axis)
#    6452 if isinstance(delegate, ExtensionArray):
#    6453     # dispatch to ExtensionArray interface
# -> 6454     return delegate._reduce(name, skipna=skipna, **kwds)
#    6456 else:
#    6457     # dispatch to numpy arrays
#    6458     if numeric_only and self.dtype.kind not in "iufcb":
#    6459         # i.e. not is_numeric_dtype(self.dtype)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:2391, in Categorical._reduce(self, name, skipna, keepdims, **kwargs)
#    2388 def _reduce(
#    2389     self, name: str, *, skipna: bool = True, keepdims: bool = False, **kwargs
#    2390 ):
# -> 2391     result = super()._reduce(name, skipna=skipna, keepdims=keepdims, **kwargs)
#    2392     if name in ["argmax", "argmin"]:
#    2393         # don't wrap in Categorical!
#    2394         return result
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/base.py:1958, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1953 if meth is None:
#    1954     raise TypeError(
#    1955         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1956         f"does not support reduction '{name}'"
#    1957     )
# -> 1958 result = meth(skipna=skipna, **kwargs)
#    1959 if keepdims:
#    1960     result = np.array([result])
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:2449, in Categorical.max(self, skipna, **kwargs)
#    2447 nv.validate_minmax_axis(kwargs.get("axis", 0))
#    2448 nv.validate_max((), kwargs)
# -> 2449 self.check_for_ordered("max")
#    2451 if not len(self._codes):
#    2452     return self.dtype.na_value
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:1901, in Categorical.check_for_ordered(self, op)
#    1899 """assert that we are ordered"""
#    1900 if not self.ordered:
# -> 1901     raise TypeError(
#    1902         f"Categorical is not ordered for operation {op}\n"
#    1903         "you can use .as_ordered() to change the "
#    1904         "Categorical to an ordered one\n"
#    1905     )
#
# TypeError: Categorical is not ordered for operation max
# you can use .as_ordered() to change the Categorical to an ordered one

# %%
df["coding_exp"] > "beginner"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df["coding_exp"] > "beginner"
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/series.py:6130, in Series._cmp_method(self, other, op)
#    6127 lvalues = self._values
#    6128 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6130 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6132 return self._construct_result(res_values, name=res_name)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:330, in comparison_op(left, right, op)
#     321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
# --> 330     res_values = op(lvalues, rvalues)
#     332 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     333     # numpy does not like comparisons vs None
#     334     if op is operator.ne:
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/arrays/categorical.py:135, in _cat_compare_op.<locals>.func(self, other)
#     133 if not self.ordered:
#     134     if opname in ["__lt__", "__gt__", "__le__", "__ge__"]:
# --> 135         raise TypeError(
#     136             "Unordered Categoricals can only compare equality or not"
#     137         )
#     138 if isinstance(other, Categorical):
#     139     # Two Categoricals can only be compared if the categories are
#     140     # the same (maybe up to ordering, depending on ordered)
#     142     msg = "Categoricals can only be compared if 'categories' are the same."
#
# TypeError: Unordered Categoricals can only compare equality or not

# %%
df["coding_exp"].cat.ordered
# Out:
# False

# %% [markdown]
# ### Converting to ordered - way 1

# %%
# The order is OK
df["coding_exp"].cat.categories
# Out:
# Index(['beginner', 'intermediate', 'pro'], dtype='object')

# %%
df["coding_exp"] = df["coding_exp"].cat.as_ordered()

# %%
df["coding_exp"]
# Out:
# 0              pro
# 1     intermediate
# 2     intermediate
# 3         beginner
# 4         beginner
#           ...
# 95             pro
# 96    intermediate
# 97    intermediate
# 98    intermediate
# 99        beginner
# Name: coding_exp, Length: 100, dtype: category
# Categories (3, object): ['beginner' < 'intermediate' < 'pro']

# %%
# Give the lowest category
df["coding_exp"].min()
# Out:
# 'beginner'

# %%
# Give the highest category
df["coding_exp"].max()
# Out:
# 'pro'

# %%
df["coding_exp"] > "beginner"
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99    False
# Name: coding_exp, Length: 100, dtype: bool

# %% [markdown]
# ### Converting to ordered - way 2 (new cat type)

# %%
df["title"]= df["title"].astype("category")

# %%
# alphabetical order
df["title"].cat.categories
# Out:
# Index(['bishop', 'king', 'knight', 'merchant', 'peasant'], dtype='object')

# %%
new_cat = CategoricalDtype(
    categories=["peasant", "merchant", "knight", "bishop", "king",],
    ordered=True
)

# %%
df["title"] = df["title"].astype(new_cat)

# %%
# specified order
df["title"].cat.categories
# Out:
# Index(['peasant', 'merchant', 'knight', 'bishop', 'king'], dtype='object')

# %%
df["title"]
# Out:
# 0      peasant
# 1         king
# 2       knight
# 3      peasant
# 4         king
#         ...
# 95      knight
# 96      knight
# 97    merchant
# 98     peasant
# 99      bishop
# Name: title, Length: 100, dtype: category
# Categories (5, object): ['peasant' < 'merchant' < 'knight' < 'bishop' < 'king']

# %% [markdown]
# ### Converting to ordered - way 3 (reorder)

# %%
df = mock_df()

# %%
df["title"]= df["title"].astype("category")

# %%
# alphabetical order
df["title"].cat.categories
# Out:
# Index(['bishop', 'king', 'knight', 'merchant', 'peasant'], dtype='object')

# %%
# Specify a new order
new_order = ['peasant', 'merchant', 'knight', 'bishop', 'king']

# %%
df["title"] = df["title"].cat.reorder_categories(new_order, ordered=True)

# %%
df["title"]
# Out:
# 0      peasant
# 1         king
# 2       knight
# 3      peasant
# 4         king
#         ...
# 95      knight
# 96      knight
# 97    merchant
# 98     peasant
# 99      bishop
# Name: title, Length: 100, dtype: category
# Categories (5, object): ['peasant' < 'merchant' < 'knight' < 'bishop' < 'king']

# %% [markdown]
# ## Create a new categorical variable.
#
# We can create new categorical columns, not just convert the existing ones.

# %%
df = mock_df()

# %%
df["secret_group"].unique()
# Out:
# array([3, 2, 4, 1])

# %% [markdown]
# We need to remember codes need to start at 0.
#
# So:
#
# 1 - code 0
# 2 - code 1 etc.

# %%
df["secret_group_name"] = pd.Categorical.from_codes(
    codes=df["secret_group"]-1,
    categories=["ones", "twos", "threes", "fours"],
    ordered=True,
)

# %%
df
# Out:
#     age    coding_exp     title fav_myth_creature fav_3_letters  secret_group  \
# 0    42           pro   peasant          Big Foot           kcx             3
# 1    44  intermediate      king          Werewolf           mvz             2
# 2    20  intermediate    knight          Big Foot           ims             4
# 3    34      beginner   peasant          Werewolf           lht             4
# 4    50      beginner      king           Vampire           xxq             1
# ..  ...           ...       ...               ...           ...           ...
# 95   29           pro    knight          Big Foot           tlg             4
# 96   30  intermediate    knight           Phoenix           lyd             4
# 97   29  intermediate  merchant           Unicorn           mqm             2
# 98   20  intermediate   peasant           Phoenix           fas             4
# 99   57      beginner    bishop           Phoenix           qah             2
#
#    secret_group_name
# 0             threes
# 1               twos
# 2              fours
# 3              fours
# 4               ones
# ..               ...
# 95             fours
# 96             fours
# 97              twos
# 98             fours
# 99              twos
#
# [100 rows x 7 columns]

# %%
df["secret_group_name"]
# Out:
# 0     threes
# 1       twos
# 2      fours
# 3      fours
# 4       ones
#        ...
# 95     fours
# 96     fours
# 97      twos
# 98     fours
# 99      twos
# Name: secret_group_name, Length: 100, dtype: category
# Categories (4, object): ['ones' < 'twos' < 'threes' < 'fours']

# %% [markdown]
# ## Dealing with missing values

# %%
df = mock_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
df["middle_agers"] = pd.cut(
    x=df["age"],
    bins=[40, 50],
    labels=["middle agers"]
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
#  6   middle_agers       18 non-null     category
# dtypes: category(1), int64(2), object(4)
# memory usage: 5.0+ KB

# %%
df
# Out:
#     age    coding_exp     title fav_myth_creature fav_3_letters  secret_group  \
# 0    42           pro   peasant          Big Foot           kcx             3
# 1    44  intermediate      king          Werewolf           mvz             2
# 2    20  intermediate    knight          Big Foot           ims             4
# 3    34      beginner   peasant          Werewolf           lht             4
# 4    50      beginner      king           Vampire           xxq             1
# ..  ...           ...       ...               ...           ...           ...
# 95   29           pro    knight          Big Foot           tlg             4
# 96   30  intermediate    knight           Phoenix           lyd             4
# 97   29  intermediate  merchant           Unicorn           mqm             2
# 98   20  intermediate   peasant           Phoenix           fas             4
# 99   57      beginner    bishop           Phoenix           qah             2
#
#     middle_agers
# 0   middle agers
# 1   middle agers
# 2            NaN
# 3            NaN
# 4   middle agers
# ..           ...
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
#
# [100 rows x 7 columns]

# %%
df["middle_agers"]
# Out:
# 0     middle agers
# 1     middle agers
# 2              NaN
# 3              NaN
# 4     middle agers
#           ...
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# Name: middle_agers, Length: 100, dtype: category
# Categories (1, object): ['middle agers']

# %%
df["middle_agers"].cat.codes
# Out:
# 0     0
# 1     0
# 2    -1
# 3    -1
# 4     0
#      ..
# 95   -1
# 96   -1
# 97   -1
# 98   -1
# 99   -1
# Length: 100, dtype: int8

# %%
# This doesn't work! Only valid categories are allowed and currently we have one
df["middle_ages"].fillna("yh?")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'middle_ages'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 2
#       1 # This doesn't work! Only valid categories are allowed and currently we have one
# ----> 2 df["middle_ages"].fillna("yh?")
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/repos/medium-WIP/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'middle_ages'

# %%
df["middle_agers"].cat.categories
# Out:
# Index(['middle agers'], dtype='object')

# %%
df["middle_agers"].cat.ordered
# Out:
# True

# %%
# This makes the category column ordered
df["middle_agers"].cat.add_categories("yh?")
# Out:
# 0     middle agers
# 1     middle agers
# 2              NaN
# 3              NaN
# 4     middle agers
#           ...
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# Name: middle_agers, Length: 100, dtype: category
# Categories (2, object): ['middle agers' < 'yh?']

# %%
df["middle_agers"].cat.add_categories("yh?").cat.as_unordered()
# Out:
# 0     middle agers
# 1     middle agers
# 2              NaN
# 3              NaN
# 4     middle agers
#           ...
# 95             NaN
# 96             NaN
# 97             NaN
# 98             NaN
# 99             NaN
# Name: middle_agers, Length: 100, dtype: category
# Categories (2, object): ['middle agers', 'yh?']

# %%
# All in one go

df["middle_agers"] = (
    df["middle_agers"]
    .cat.add_categories("yh?")
    .cat.as_unordered()
    .fillna("yh?")
)

# %%
df["middle_agers"]
# Out:
# 0     middle agers
# 1     middle agers
# 2              yh?
# 3              yh?
# 4     middle agers
#           ...
# 95             yh?
# 96             yh?
# 97             yh?
# 98             yh?
# 99             yh?
# Name: middle_agers, Length: 100, dtype: category
# Categories (2, object): ['middle agers', 'yh?']

# %%
df["middle_agers"].value_counts(dropna=False)
# Out:
# middle_agers
# yh?             82
# middle agers    18
# Name: count, dtype: int64

# %% [markdown]
# ## Using ordered categories with `groupby` and filtering

# %%
df = mock_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
# As column as string
grouped = df[["age", "title"]].groupby(by="title").mean()

# %%
# Alphabetical order, OK, but perhaps not great
grouped
# Out:
#                 age
# title
# bishop    37.842105
# king      42.789474
# knight    41.833333
# merchant  45.611111
# peasant   40.450000

# %%
# Swap "title" column to ordered categorical
new_order = ['peasant', 'merchant', 'knight', 'bishop', 'king']

# %%
df["title"] = (
    df["title"]
    .astype("category")
    .cat.reorder_categories(new_order, ordered=True)
)

# %%
# groupby once again
grouped = df[["age", "title"]].groupby(by="title", observed=False).mean()

# %%
grouped
# Out:
#                 age
# title
# peasant   40.450000
# merchant  45.611111
# knight    41.833333
# bishop    37.842105
# king      42.789474

# %% [markdown]
# ### Add more categories

# %%
df["title"]=df["title"].cat.add_categories("god")

# %%
grouped = df[["age", "title"]].groupby(by="title", observed=False).mean()

# %%
grouped
# Out:
#                 age
# title
# peasant   40.450000
# merchant  45.611111
# knight    41.833333
# bishop    37.842105
# king      42.789474
# god             NaN

# %%
grouped = df[["age", "title"]].groupby(by="title", observed=True).mean()

# %%
grouped
# Out:
#                 age
# title
# peasant   40.450000
# merchant  45.611111
# knight    41.833333
# bishop    37.842105
# king      42.789474

# %% [markdown]
# ### Filtering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    category
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: category(1), int64(2), object(3)
# memory usage: 4.3+ KB

# %%
df.title
# Out:
# 0      peasant
# 1         king
# 2       knight
# 3      peasant
# 4         king
#         ...
# 95      knight
# 96      knight
# 97    merchant
# 98     peasant
# 99      bishop
# Name: title, Length: 100, dtype: category
# Categories (6, object): ['peasant' < 'merchant' < 'knight' < 'bishop' < 'king' < 'god']

# %%
mask = df["title"] > "merchant"

# %%
only_noblemen = df[mask].copy()

# %%
only_noblemen
# Out:
#     age    coding_exp   title fav_myth_creature fav_3_letters  secret_group
# 1    44  intermediate    king          Werewolf           mvz             2
# 2    20  intermediate  knight          Big Foot           ims             4
# 4    50      beginner    king           Vampire           xxq             1
# 6    43      beginner  knight          Big Foot           bct             2
# 7    37      beginner  bishop            Dragon           bak             4
# ..  ...           ...     ...               ...           ...           ...
# 91   38  intermediate    king           Phoenix           ifh             3
# 93   33      beginner  bishop           Vampire           hor             2
# 95   29           pro  knight          Big Foot           tlg             4
# 96   30  intermediate  knight           Phoenix           lyd             4
# 99   57      beginner  bishop           Phoenix           qah             2
#
# [62 rows x 6 columns]

# %%
only_noblemen["title"].unique()
# Out:
# ['king', 'knight', 'bishop']
# Categories (6, object): ['peasant' < 'merchant' < 'knight' < 'bishop' < 'king' < 'god']

# %%
only_noblemen["title"].value_counts(dropna=False)
# Out:
# title
# knight      24
# bishop      19
# king        19
# peasant      0
# merchant     0
# god          0
# Name: count, dtype: int64

# %%
# Remove unwanted categories
only_noblemen["title"] = only_noblemen["title"].cat.remove_unused_categories()

# %%
only_noblemen["title"]
# Out:
# 1       king
# 2     knight
# 4       king
# 6     knight
# 7     bishop
#        ...
# 91      king
# 93    bishop
# 95    knight
# 96    knight
# 99    bishop
# Name: title, Length: 62, dtype: category
# Categories (3, object): ['knight' < 'bishop' < 'king']

# %%
only_noblemen["title"].unique()
# Out:
# ['king', 'knight', 'bishop']
# Categories (3, object): ['knight' < 'bishop' < 'king']

# %% [markdown]
# ## Memory and speed comparison

# %%
# df = mock_df(nr_of_samples=20_000_000)
df = mock_df(nr_of_samples=20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                20 non-null     int64
#  1   coding_exp         20 non-null     object
#  2   title              20 non-null     object
#  3   fav_myth_creature  20 non-null     object
#  4   fav_3_letters      20 non-null     object
#  5   secret_group       20 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
df[["age", "title", "coding_exp"]].groupby(["coding_exp", "title"]).count()
# Out:
#                        age
# coding_exp   title
# beginner     bishop      1
#              king        1
#              merchant    2
#              peasant     1
# intermediate bishop      2
#              king        1
#              merchant    1
#              peasant     3
# pro          bishop      2
#              king        2
#              knight      3
#              peasant     1

# %%
df["title"] = df["title"].astype("category")
df["coding_exp"] = df["coding_exp"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                20 non-null     int64
#  1   coding_exp         20 non-null     category
#  2   title              20 non-null     category
#  3   fav_myth_creature  20 non-null     object
#  4   fav_3_letters      20 non-null     object
#  5   secret_group       20 non-null     int64
# dtypes: category(2), int64(2), object(2)
# memory usage: 1.1+ KB

# %%
df[["age", "title", "coding_exp"]].groupby(["coding_exp", "title"], observed=False).count()
# Out:
#                        age
# coding_exp   title
# beginner     bishop      1
#              king        1
#              knight      0
#              merchant    2
#              peasant     1
# intermediate bishop      2
#              king        1
#              knight      0
#              merchant    1
#              peasant     3
# pro          bishop      2
#              king        2
#              knight      3
#              merchant    0
#              peasant     1

# %% [markdown]
# ## Tips

# %% [markdown]
# ### Read from csv + specify types

# %% [markdown]
# ### Select columns for convertions

# %%
df = mock_df()

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['coding_exp', 'title', 'fav_myth_creature', 'fav_3_letters'], dtype='object')

# %%
df.select_dtypes(include="object").columns.drop("fav_3_letters")
# Out:
# Index(['coding_exp', 'title', 'fav_myth_creature'], dtype='object')

# %%
cols_to_convert = df.select_dtypes(include="object").columns.drop("fav_3_letters")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
df[cols_to_convert] = df[cols_to_convert].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    category
#  2   title              100 non-null    category
#  3   fav_myth_creature  100 non-null    category
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: category(3), int64(2), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# ### Mapping

# %%
# Example DataFrame with NaN values
data = {
    'Category': ['A', 'B', np.nan, 'C', 'B', 'D', 'E', np.nan, 'C'],
    'Value': [10, 20, 30, 40, 50, 60, 70, 80, 90]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Value
# 0        A     10
# 1        B     20
# 2      NaN     30
# 3        C     40
# 4        B     50
# 5        D     60
# 6        E     70
# 7      NaN     80
# 8        C     90

# %%
# Include NaN as a group and get first occurrence
first_occurrences = df.groupby('Category', dropna=False, as_index=False).first()

print(first_occurrences)
# Out:
#   Category  Value
# 0        A     10
# 1        B     20
# 2        C     40
# 3        D     60
# 4        E     70
# 5      NaN     30

# %%
first_occurrences["Category"].astype("category").cat.codes
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# 5   -1
# dtype: int8

# %%
first_occurrences["Category"].astype("category").cat.codes
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# 5   -1
# dtype: int8

# %%
first_occurrences["Category"].astype("category").cat.categories
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# ### Int can be categorical too!
#
# Strings make most sense to be used as categorical but they aren't the only ones that can be converted!

# %%
df = mock_df()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                100 non-null    int64
#  1   coding_exp         100 non-null    object
#  2   title              100 non-null    object
#  3   fav_myth_creature  100 non-null    object
#  4   fav_3_letters      100 non-null    object
#  5   secret_group       100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
df["secret_group"].unique()
# Out:
# array([3, 2, 4, 1])

# %%
df["secret_group"] = df["secret_group"].astype("category")

# %%
df["secret_group"]
# Out:
# 0     3
# 1     2
# 2     4
# 3     4
# 4     1
#      ..
# 95    4
# 96    4
# 97    2
# 98    4
# 99    2
# Name: secret_group, Length: 100, dtype: category
# Categories (4, int64): [1, 2, 3, 4]
